# %% [markdown]
# <a href="https://colab.research.google.com/github/cs-pub-ro/ML/blob/master/lab2/Laborator_2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Învățare Automată
# # Arbori de decizie. Păduri aleatoare
# ### Autori:
# * Tudor Berariu - 2016
# * George Muraru - 2020

# %% [markdown]
# ## 1. Scopul laboratorului
# Scopul laboratorului îl reprezintă întelegerea conceptului de arbore de decizie și implementarea unor clasificatori bazați pe acest model.

# %% [markdown]
# ## 2. Problema de rezolvat
# Problema de rezolvat ı̂n acest laborator este una de ı̂nvățare supervizată: fiind dat un **set de date X** ce conține exemple descrise printr-un set de **atribute discrete A** și etichetate cu **câte o clasă dintr-o mulțime cunoscută C**, să se construiască un model pentru clasificarea exemplelor noi.

# %% [markdown]
# ## 3. Arbore de decizie
# Un arbore de decizie este un clasificator ce aproximează funcții discrete.
#
# Într-un arbore de decizie există 2 tipuri de noduri:
# * *noduri intermediare* - conține un test pentru un atribut și are câte un arc (și implicit un subarbore) pentru fiecare valoare posibiliă a atributului
# * *noduri frunză* - este etichetat cu o clasă
#
# Pentru **a clasifica un obiect nou** se pornește din rădăcina arborelui și din fiecare nod se coboară pe arcul corespunzător valorii atributului pe care o are obiectul dat. Atunci când se ajunge ı̂ntr-un nod frunză, clasa acestuia va reprezenta predicția arborelui.

# %% [markdown]
# ## 4. Păduri de arbori aleatori
# *Pădurile de arbori aleatori* (eng. Random Forest) este un model format din mai mulți arbori de decizie.
#
# Se bazează pe 2 hiperparametri:
# * Eșantionare aleatoare din setul de date de antrenament
# * Subseturi aleatoare de atribute considerate la împărțirea pe mai multi subarbori
#
# Predicția, utilizând un astfel de model, se bazează pe clasa majoritară oferită de predicțiile indepente ale tuturor arborilor.

# %% [markdown]
# ## 5. Workspace Setup
# ### Câteva biblioteci de care vom avea nevoie

# %%
from collections import Counter
from copy import deepcopy
import csv
from math import inf, log2
from numpy import array_split
from random import choice, shuffle

# %% [markdown]
# ### Hiperparametrii necesari rulării

# %%
DATASET_NAME = 'Car'  #@param ['Chess', 'Car', 'Tennis']

# Adâncimea arborilor
D = 3 #@param {type: "slider", min: 2, max: 10}

# Procentul de exemple din setul de date utilizat la construcția arborilor
P = 50 #@param {type: "slider", min: 1, max: 100}

# %% [markdown]
# ### Funcții ajutătoare pentru descărcarea și lucrul cu setul de date

# %%
class Node:
    """ Representation for a node from the decision tree """
    def __init__(self, label):
        """
            for non-leafs it is the name of the attribute
            for leafs it is the class
        """
        self.label = label
        
        # Dictionary of (attribute value, nodes)
        self.children = {}
    
    def display(self, string):
        print(string + self.label)
        string += "\t"
        if self.children:
            for key, value in self.children.items():
                print(string + key)
                value.display(string + "\t")


def getArchive(dataSetName):
    """ Checks if a specific dataset is present in the local directory, if not,
    downloads it.

    Args:
        dataSetName (str): the dataset name
    """
    datasets_url = {
        "Car": "https://raw.githubusercontent.com/cs-pub-ro/ML/master/lab/lab2/datasets/car",
        "Chess": "https://raw.githubusercontent.com/cs-pub-ro/ML/master/lab2/datasets/chess",
        "Tennis": "https://raw.githubusercontent.com/cs-pub-ro/ML/master/lab2/datasets/tennis"
    }

    assert dataSetName in datasets_url

    from os import sep, path    
    dataset_url = datasets_url[dataSetName]
    dataset_file = os.sep.join(os.path.normpath(dataset_url).split(os.sep)[-2:])
    print(dataset_file)

    if not path.isfile(dataset_file):
        import urllib
        print("Downloading...")
        urllib.request.urlretrieve(dataset_url, filename=dataset_file)
        assert(path.isfile(dataset_file))
        print("Got the archive")
    else:
        print(f"{dataset_file} already in the local directory")


def getDataSet(dataSetName):
    """ Reads a dataset

    Args:
        dataSetName (str): Name for the dataset

    Returns:
        A tuple containing (classes, attributes, examples):
        classes (set): the classes that are found in the dataset
        attributes (list of strings): the attributes for the dataset
        examples (list of dictionaries): one example contains an entry as
            (attribute name, attribute value)
    """

    dataset_file = f'datasets/{dataSetName.lower()}'

    f_in = open(dataset_file, 'r')
    csv_reader = csv.reader(f_in, delimiter=",")

    # Read the header row
    row = next(csv_reader)

    # The last element represents the class
    attributeNames = row[:-1]
    
    examples = []
    classes = set()

    for row in csv_reader:
        *attributes, label = row
        classes.add(label)
        example = dict(zip(attributeNames, attributes))
        example["CLASS"] = label
        examples.append(example)
    
    f_in.close()
    return classes, attributeNames, examples

# %% [markdown]
# ### Descărcare și încarcare set de date

# %%
getArchive(DATASET_NAME)
classes, attributes, examples = getDataSet(DATASET_NAME)
examples
attributes

print(examples[0])
print(attributes)
# Out:
# datasets/car
# datasets/car already in the local directory
# {'buying': 'vhigh', 'maint': 'vhigh', 'doors': '2', 'persons': '2', 'lug_boot': 'small', 'CLASS': 'unacc'}
# ['buying', 'maint', 'doors', 'persons', 'lug_boot']

# %% [markdown]
# ## 6. Cerințe

# %% [markdown]
# 1. [3 pct] Implementați o funcție recursivă *randomTree* care construiește arbori de decizie de adâncime **d** pe baza unui **set de date X** și a unei **mulțimi de atribute A** astfel:
#  * Dacă *d = 0*, atunci se construiește un nod frunză cu clasa majoritară din X.
#  * Dacă *d > 0*, atunci se alege aleator un atribut $a_i$ din A și se construiește câte un subarbore pentru fiecare valoare $v_j$ a atributului $a_i$ apelând *randomTree* pentru *d − 1*:
# $$
# X_{i/j} = \{x \in X|a_{i}(x) = v_k\}\\
# A_{new} = A \setminus \{a_i\}
# $$

# %%
def decisionTree(d, X, A, alg, chooser):
   if not d or not A:
      return Node(Counter([x['CLASS'] for x in X]).most_common()[0][0])
   if alg == 'id3' \
      and all(map(lambda x: x['CLASS'] == X[0]['CLASS'], X)):
      return Node(X[0]['CLASS'])

   attrib = chooser(X, A)
   Vs = set([x[attrib] for x in X])
   A_new = deepcopy(A)
   A_new.remove(attrib)

   node = Node(attrib)
   node.children = {
      v: decisionTree(
         d - 1,
         [x for x in X if x[attrib] == v],
         A_new,
         alg,
         chooser
      )
         for v in Vs
   }

   return node


def randomTree(d, X, A):
   # Cerință 1
   return decisionTree(d, X, A, 'random', lambda _, A: choice(A))


root = randomTree(2, examples, attributes)
root.display('-> ')
# Out:
# -> maint
# -> 	med
# -> 		buying
# -> 			med
# -> 				unacc
# -> 			high
# -> 				unacc
# -> 			low
# -> 				unacc
# -> 			vhigh
# -> 				unacc
# -> 	high
# -> 		persons
# -> 			more
# -> 				unacc
# -> 			4
# -> 				unacc
# -> 			2
# -> 				unacc
# -> 	low
# -> 		doors
# -> 			4
# -> 				unacc
# -> 			2
# -> 				unacc
# -> 			3
# -> 				unacc
# -> 			5more
# -> 				unacc
# -> 	vhigh
# -> 		buying
# -> 			med
# -> 				unacc
# -> 			high
# -> 				unacc
# -> 			low
# -> 				unacc
# -> 			vhigh
# -> 				unacc

# %% [markdown]
# 2. [3 pct] Implementați o funcție recursivă *id3* care construiește arbori de decizie pe baza unui **set de date X** și a unei **mulțimi de atribute A**.
#
#   Trebuie avute în vedere următoarele aspecte:
#   * dacă toate exemplele din X aparțin unei singure clase C, atunci se construiește un nod frunză etichetat cu acea clasă C
#   * dacă nu mai exista atribute, atunci construiește nodul frunză etichetat cu cea mai frecventă clasă din X
#
#   În caz contrar:
#   * se alege atributul $a^*$ care aduce cel mai mai mare câștig informațional și se construiește un *nod intermediar* corespunzător acestuia.
#
#   $$
#     entropy(X) = -\sum_{c \in C}\frac{|X_c|}{|X|}log_2\frac{|X_c|}{|X|}
#   $$
#   $$
#     gain(X, a) = entropy(X) - \sum_{v_{j} \in vals(a)} \frac{|X_{i/j}|}{|X|}entropy(X_{i/j})
#   $$
#   $$
#     a^* = \underset{a \in A}{\operatorname{arg max}}\ gain(X, a)
#   $$
#
#   * pentru fiecare valoare posibilă $v_j$ a lui $a^*$ se construiește un subarbore apelând recursiv funcția *id3* pentru:
#
# $$
#   X_j = \{x \in X|a^*(x) = v_j\}\\
#   A_{new} = A\setminus\{a^*\}
# $$
#
# În cazul prezentat mai sus, entropia este utilizată pentru a măsura randomness-ul din date. Intuitiv, cu cât un eveniment are probabilitate mai mare să se întâmple atunci acesta va avea o entropia din ce în ce mai mică. Prin modul în care se construiește arborele *ID3* se încearcă reducerea entropiei alegând la fiecare pas atributele care ne ofera cea mai multă informație. Cât considerați că este entropia într-un *nod frunză*?

# %%
def mostFrequentClass(X):
    # TODO Cerință 2
    return Counter([x['CLASS'] for x in X]).most_common()[0][0]


def entropy(X):
    # TODO Cerință 2
    classes = {}
    for x in X:
        if x['CLASS'] in classes:
            classes[x['CLASS']] += 1
        else:
            classes[x['CLASS']] = 1

    return -sum(num / len(X) * log2(num / len(X))
        for _, num in classes.items())


def gain(X, a):
    # TODO Cerință 2
    Vs = set([x[a] for x in X])
    l = len(X)
    gain = entropy(X)

    for v in Vs:
        X_new = [x for x in X if x[a] == v]
        gain -= len(X_new) * entropy(X_new) / l

    return gain  


def getMaxGainAttrib(X, A):
    max_gain = -inf

    for attr in A:
        crt_gain = gain(X, attr)
        if crt_gain > max_gain:
            max_gain = crt_gain
            attrib = attr

    return attrib


def id3(X, A):
    # TODO Cerință 2
    return decisionTree(-1, X, A, 'id3', getMaxGainAttrib)


def evaluate(tree, example):
    # TODO Cerință 2
    # Functia intoarce clasa prezisa de arborele `tree` pentru exemplul `example`
    if not tree.children:
        return tree.label
    if example[tree.label] not in tree.children:
        return evaluate(list(tree.children.values())[0], example)
    return evaluate(tree.children[example[tree.label]], example)

# %% [markdown]
# 3. [4 pct] Implementați clasificator de tip pădure de arbori aleatori construind *n* arbori de adâncime maximă *d* fiecare dintre aceștia pornind de la o submulțime aleatoare a lui X.
#
#     Folosiți funcția *randomTree* de la cerința 1.
#   * Porniți de la *n = 100*, *d = 3* și submulțimi formate din 50% din elementele lui X alese la întamplare și experimentați cu acești hiperparametri.
#   * Pentru predicția clasei pentru obiecte noi alegeți clasa majoritară
#   * Comparați rezultatele obținute folosind un singur arbore construit cu ID3 și o pădure de arbori aleatori. Discuție după *zgomot*, *overfitting*.

# %%
def randomForest(X, A, n, d):
    # TODO Cerință 3
    shuffle(X)
    return [randomTree(d, list(chunk), A) for chunk in array_split(X, n)]


def randomID3Forest(X, A, n):
    shuffle(X)
    return [id3(list(chunk), A) for chunk in array_split(X, n)]


def evaluateForest(forest, x):
    return Counter(list(map(lambda t: evaluate(t, x), forest))).most_common()[0][0]


def precision(tree, X, c, type):
    prec = 0
    predicted_ct = 0
    evaluator = evaluate if type == 'tree' else evaluateForest
    
    for ex in X:
        pred_c = evaluator(tree, ex)
        if pred_c == c:
            predicted_ct += 1
            if ex['CLASS'] ==c:
                prec += 1
    
    if predicted_ct != 0:
        return prec / predicted_ct
    return 0


def recall(tree, X, c, type):
    X_c = list(filter(lambda ex: ex['CLASS'] == c, X))
    recall = 0
    evaluator = evaluate if type == 'tree' else evaluateForest
    
    for ex in X_c:
        pred_c = evaluator(tree, ex)
        if pred_c == c:
            recall += 1
            
    recall /= len(X_c)
    return recall


def accuracy(tree, X, type):
    count = 0
    evaluator = evaluate if type == 'tree' else evaluateForest

    for x in X:
        if evaluator(tree, x) == x['CLASS']:
            count += 1
    
    return 1.0 * count / len(X)


def test_algs(root, X, type, tabs):
    for clss in set([x['CLASS'] for x in X]):
        print(tabs * '\t' + f'prec for class {clss} = {precision(root, X, clss, type)}')
        print(tabs * '\t' + f'recall for class {clss} = {recall(root, X, clss, type)}')
        print()
    print(tabs * '\t' + f'acc = {accuracy(root, X, type)}')

# %%
DATASETS = ['Car', 'Chess', 'Tennis']

for ds in DATASETS:
    classes, attributes, examples = getDataSet(ds)
    print(f'Testing dataset {ds}')

    print(f'\tTesting randomTree:')
    for d in range(2, 6):
        print(f'\t\td = {d}:')
        tree = randomTree(d, examples, attributes)
        test_algs(tree, examples, 'tree', 2)
        print()
    
    print(f'\tTesting ID3:')
    tree = id3(examples, attributes)
    test_algs(tree, examples, 'tree', 1)
    print()

    print('\tTesting randomForest with randomTrees:')
    for n in range(10, 100, 10):
        print(f'\t\tn = {n}')
        for d in range(2, 6):
            print(f'\t\t\td = {d}:')
            forest = randomForest(examples, attributes, n, d)
            test_algs(forest, examples, 'forest', 3)
            print()
# Out:
# Testing dataset Car
# 	Testing randomTree:
# 		d = 2:
# 		prec for class acc = 0
# 		recall for class acc = 0.0
#
# 		prec for class good = 0
# 		recall for class good = 0.0
#
# 		prec for class unacc = 0.7002314814814815
# 		recall for class unacc = 1.0
#
# 		prec for class vgood = 0
# 		recall for class vgood = 0.0
#
# 		acc = 0.7002314814814815
#
# 		d = 3:
# 		prec for class acc = 0.4166666666666667
# 		recall for class acc = 0.1171875
#
# 		prec for class good = 0
# 		recall for class good = 0.0
#
# 		prec for class unacc = 0.7209876543209877
# 		recall for class unacc = 0.9652892561983472
#
# 		prec for class vgood = 0
# 		recall for class vgood = 0.0
#
# 		acc = 0.7019675925925926
#
# 		d = 4:
# 		prec for class acc = 0.5833333333333334
# 		recall for class acc = 0.3463541666666667
#
# 		prec for class good = 0
# 		recall for class good = 0.0
#
# 		prec for class unacc = 0.7526666666666667
# 		recall for class unacc = 0.9330578512396694
#
# 		prec for class vgood = 0
# 		recall for class vgood = 0.0
#
# 		acc = 0.7303240740740741
#
# 		d = 5:
# 		prec for class acc = 0.6666666666666666
# 		recall for class acc = 0.6458333333333334
#
# 		prec for class good = 0
# 		recall for class good = 0.0
#
# 		prec for class unacc = 0.8008849557522124
# 		recall for class unacc = 0.8975206611570248
#
# 		prec for class vgood = 0
# 		recall for class vgood = 0.0
#
# 		acc = 0.7719907407407407
#
# 	Testing ID3:
# 	prec for class acc = 0.6666666666666666
# 	recall for class acc = 0.6458333333333334
#
# 	prec for class good = 0
# 	recall for class good = 0.0
#
# 	prec for class unacc = 0.8008849557522124
# 	recall for class unacc = 0.8975206611570248
#
# 	prec for class vgood = 0
# 	recall for class vgood = 0.0
#
# 	acc = 0.7719907407407407
#
# 	Testing randomForest with randomTrees:
# 		n = 10
# 			d = 2:
# 			prec for class acc = 0
# 			recall for class acc = 0.0
#
# 			prec for class good = 0
# 			recall for class good = 0.0
#
# 			prec for class unacc = 0.7002314814814815
# 			recall for class unacc = 1.0
#
# 			prec for class vgood = 0
# 			recall for class vgood = 0.0
#
# 			acc = 0.7002314814814815
#
# 			d = 3:
# 			prec for class acc = 0.39215686274509803
# 			recall for class acc = 0.052083333333333336
#
# 			prec for class good = 0
# 			recall for class good = 0.0
#
# 			prec for class unacc = 0.7090800477897252
# 			recall for class unacc = 0.9809917355371901
#
# 			prec for class vgood = 0.3333333333333333
# 			recall for class vgood = 0.015384615384615385
#
# 			acc = 0.6990740740740741
#
# 			d = 4:
# 			prec for class acc = 0.46875
# 			recall for class acc = 0.234375
#
# 			prec for class good = 0.3333333333333333
# 			recall for class good = 0.057971014492753624
#
# 			prec for class unacc = 0.7442472057856673
# 			recall for class unacc = 0.9355371900826446
#
# 			prec for class vgood = 0.3333333333333333
# 			recall for class vgood = 0.015384615384615385
#
# 			acc = 0.7100694444444444
#
# 			d = 5:
# 			prec for class good = 0.3333333333333333
# 			recall for class good = 0.10144927536231885
#
# 			prec for class acc = 0.524390243902439
# 			recall for class acc = 0.3359375
#
# 			prec for class unacc = 0.7636867636867637
# 			recall for class unacc = 0.9107438016528926
#
# 			prec for class vgood = 0.3333333333333333
# 			recall for class vgood = 0.09230769230769231
#
# 			acc = 0.7199074074074074
#
# 		n = 20
# 			d = 2:
# 			prec for class acc = 0
# 			recall for class acc = 0.0
#
# 			prec for class good = 0
# 			recall for class good = 0.0
#
# 			prec for class unacc = 0.7002314814814815
# 			recall for class unacc = 1.0
#
# 			prec for class vgood = 0
# 			recall for class vgood = 0.0
#
# 			acc = 0.7002314814814815
#
# 			d = 3:
# 			prec for class acc = 0.4090909090909091
# 			recall for class acc = 0.0703125
#
# 			prec for class good = 0
# 			recall for class good = 0.0
#
# 			prec for class unacc = 0.7148014440433214
# 			recall for class unacc = 0.9818181818181818
#
# 			prec for class vgood = 0
# 			recall for class vgood = 0.0
#
# 			acc = 0.703125
#
# 			d = 4:
# 			prec for class acc = 0.4583333333333333
# 			recall for class acc = 0.14322916666666666
#
# 			prec for class good = 0.3333333333333333
# 			recall for class good = 0.028985507246376812
#
# 			prec for class unacc = 0.7298311444652908
# 			recall for class unacc = 0.9644628099173553
#
# 			prec for class vgood = 0.3333333333333333
# 			recall for class vgood = 0.015384615384615385
#
# 			acc = 0.7089120370370371
#
# 			d = 5:
# 			prec for class acc = 0.5507246376811594
# 			recall for class acc = 0.296875
#
# 			prec for class good = 0.3333333333333333
# 			recall for class good = 0.014492753623188406
#
# 			prec for class unacc = 0.7430830039525692
# 			recall for class unacc = 0.9322314049586777
#
# 			prec for class vgood = 0
# 			recall for class vgood = 0.0
#
# 			acc = 0.7193287037037037
#
# 		n = 30
# 			d = 2:
# 			prec for class good = 0
# 			recall for class good = 0.0
#
# 			prec for class acc = 0
# 			recall for class acc = 0.0
#
# 			prec for class unacc = 0.7002314814814815
# 			recall for class unacc = 1.0
#
# 			prec for class vgood = 0
# 			recall for class vgood = 0.0
#
# 			acc = 0.7002314814814815
#
# 			d = 3:
# 			prec for class acc = 0.5
# 			recall for class acc = 0.0625
#
# 			prec for class good = 0
# 			recall for class good = 0.0
#
# 			prec for class unacc = 0.7107142857142857
# 			recall for class unacc = 0.9867768595041322
#
# 			prec for class vgood = 0
# 			recall for class vgood = 0.0
#
# 			acc = 0.7048611111111112
#
# 			d = 4:
# 			prec for class acc = 0.43859649122807015
# 			recall for class acc = 0.06510416666666667
#
# 			prec for class good = 0
# 			recall for class good = 0.0
#
# 			prec for class unacc = 0.7127468581687613
# 			recall for class unacc = 0.984297520661157
#
# 			prec for class vgood = 0
# 			recall for class vgood = 0.0
#
# 			acc = 0.7037037037037037
#
# 			d = 5:
# 			prec for class acc = 0.5
# 			recall for class acc = 0.0859375
#
# 			prec for class good = 0
# 			recall for class good = 0.0
#
# 			prec for class unacc = 0.7142857142857143
# 			recall for class unacc = 0.9793388429752066
#
# 			prec for class vgood = 0.3333333333333333
# 			recall for class vgood = 0.015384615384615385
#
# 			acc = 0.7054398148148148
#
# 		n = 40
# 			d = 2:
# 			prec for class good = 0
# 			recall for class good = 0.0
#
# 			prec for class acc = 0
# 			recall for class acc = 0.0
#
# 			prec for class unacc = 0.7002314814814815
# 			recall for class unacc = 1.0
#
# 			prec for class vgood = 0
# 			recall for class vgood = 0.0
#
# 			acc = 0.7002314814814815
#
# 			d = 3:
# 			prec for class acc = 0.5757575757575758
# 			recall for class acc = 0.049479166666666664
#
# 			prec for class good = 0
# 			recall for class good = 0.0
#
# 			prec for class unacc = 0.7073746312684366
# 			recall for class unacc = 0.990909090909091
#
# 			prec for class vgood = 0
# 			recall for class vgood = 0.0
#
# 			acc = 0.7048611111111112
#
# 			d = 4:
# 			prec for class acc = 0.4166666666666667
# 			recall for class acc = 0.013020833333333334
#
# 			prec for class good = 0
# 			recall for class good = 0.0
#
# 			prec for class unacc = 0.7016317016317016
# 			recall for class unacc = 0.9950413223140496
#
# 			prec for class vgood = 0
# 			recall for class vgood = 0.0
#
# 			acc = 0.6996527777777778
#
# 			d = 5:
# 			prec for class acc = 0.5
# 			recall for class acc = 0.03125
#
# 			prec for class good = 0
# 			recall for class good = 0.0
#
# 			prec for class unacc = 0.704225352112676
# 			recall for class unacc = 0.9917355371900827
#
# 			prec for class vgood = 0
# 			recall for class vgood = 0.0
#
# 			acc = 0.7013888888888888
#
# 		n = 50
# 			d = 2:
# 			prec for class acc = 0
# 			recall for class acc = 0.0
#
# 			prec for class good = 0
# 			recall for class good = 0.0
#
# 			prec for class unacc = 0.7002314814814815
# 			recall for class unacc = 1.0
#
# 			prec for class vgood = 0
# 			recall for class vgood = 0.0
#
# 			acc = 0.7002314814814815
#
# 			d = 3:
# 			prec for class good = 0
# 			recall for class good = 0.0
#
# 			prec for class acc = 0.6666666666666666
# 			recall for class acc = 0.005208333333333333
#
# 			prec for class unacc = 0.7008695652173913
# 			recall for class unacc = 0.9991735537190083
#
# 			prec for class vgood = 0
# 			recall for class vgood = 0.0
#
# 			acc = 0.7008101851851852
#
# 			d = 4:
# 			prec for class acc = 0.4166666666666667
# 			recall for class acc = 0.013020833333333334
#
# 			prec for class good = 0
# 			recall for class good = 0.0
#
# 			prec for class unacc = 0.7027972027972028
# 			recall for class unacc = 0.996694214876033
#
# 			prec for class vgood = 0
# 			recall for class vgood = 0.0
#
# 			acc = 0.7008101851851852
#
# 			d = 5:
# 			prec for class acc = 0.5128205128205128
# 			recall for class acc = 0.052083333333333336
#
# 			prec for class good = 0
# 			recall for class good = 0.0
#
# 			prec for class unacc = 0.7081113084665482
# 			recall for class unacc = 0.9884297520661157
#
# 			prec for class vgood = 0
# 			recall for class vgood = 0.0
#
# 			acc = 0.7037037037037037
#
# 		n = 60
# 			d = 2:
# 			prec for class acc = 0
# 			recall for class acc = 0.0
#
# 			prec for class good = 0
# 			recall for class good = 0.0
#
# 			prec for class unacc = 0.7002314814814815
# 			recall for class unacc = 1.0
#
# 			prec for class vgood = 0
# 			recall for class vgood = 0.0
#
# 			acc = 0.7002314814814815
#
# 			d = 3:
# 			prec for class acc = 0.6666666666666666
# 			recall for class acc = 0.005208333333333333
#
# 			prec for class good = 0
# 			recall for class good = 0.0
#
# 			prec for class unacc = 0.7008695652173913
# 			recall for class unacc = 0.9991735537190083
#
# 			prec for class vgood = 0
# 			recall for class vgood = 0.0
#
# 			acc = 0.7008101851851852
#
# 			d = 4:
# 			prec for class acc = 0.6666666666666666
# 			recall for class acc = 0.015625
#
# 			prec for class good = 0
# 			recall for class good = 0.0
#
# 			prec for class unacc = 0.702152414194299
# 			recall for class unacc = 0.9975206611570248
#
# 			prec for class vgood = 0
# 			recall for class vgood = 0.0
#
# 			acc = 0.7019675925925926
#
# 			d = 5:
# 			prec for class good = 0
# 			recall for class good = 0.0
#
# 			prec for class acc = 0.5
# 			recall for class acc = 0.0234375
#
# 			prec for class unacc = 0.704093567251462
# 			recall for class unacc = 0.9950413223140496
#
# 			prec for class vgood = 0
# 			recall for class vgood = 0.0
#
# 			acc = 0.7019675925925926
#
# 		n = 70
# 			d = 2:
# 			prec for class acc = 0
# 			recall for class acc = 0.0
#
# 			prec for class good = 0
# 			recall for class good = 0.0
#
# 			prec for class unacc = 0.7002314814814815
# 			recall for class unacc = 1.0
#
# 			prec for class vgood = 0
# 			recall for class vgood = 0.0
#
# 			acc = 0.7002314814814815
#
# 			d = 3:
# 			prec for class acc = 0.0
# 			recall for class acc = 0.0
#
# 			prec for class good = 0
# 			recall for class good = 0.0
#
# 			prec for class unacc = 0.7008695652173913
# 			recall for class unacc = 0.9991735537190083
#
# 			prec for class vgood = 0
# 			recall for class vgood = 0.0
#
# 			acc = 0.6996527777777778
#
# 			d = 4:
# 			prec for class acc = 0
# 			recall for class acc = 0.0
#
# 			prec for class good = 0
# 			recall for class good = 0.0
#
# 			prec for class unacc = 0.7002314814814815
# 			recall for class unacc = 1.0
#
# 			prec for class vgood = 0
# 			recall for class vgood = 0.0
#
# 			acc = 0.7002314814814815
#
# 			d = 5:
# 			prec for class acc = 0
# 			recall for class acc = 0.0
#
# 			prec for class good = 0
# 			recall for class good = 0.0
#
# 			prec for class unacc = 0.7002314814814815
# 			recall for class unacc = 1.0
#
# 			prec for class vgood = 0
# 			recall for class vgood = 0.0
#
# 			acc = 0.7002314814814815
#
# 		n = 80
# 			d = 2:
# 			prec for class acc = 0
# 			recall for class acc = 0.0
#
# 			prec for class good = 0
# 			recall for class good = 0.0
#
# 			prec for class unacc = 0.7002314814814815
# 			recall for class unacc = 1.0
#
# 			prec for class vgood = 0
# 			recall for class vgood = 0.0
#
# 			acc = 0.7002314814814815
#
# 			d = 3:
# 			prec for class acc = 0
# 			recall for class acc = 0.0
#
# 			prec for class good = 0
# 			recall for class good = 0.0
#
# 			prec for class unacc = 0.7002314814814815
# 			recall for class unacc = 1.0
#
# 			prec for class vgood = 0
# 			recall for class vgood = 0.0
#
# 			acc = 0.7002314814814815
#
# 			d = 4:
# 			prec for class acc = 0.5666666666666667
# 			recall for class acc = 0.044270833333333336
#
# 			prec for class good = 0
# 			recall for class good = 0.0
#
# 			prec for class unacc = 0.7067137809187279
# 			recall for class unacc = 0.9917355371900827
#
# 			prec for class vgood = 0
# 			recall for class vgood = 0.0
#
# 			acc = 0.7042824074074074
#
# 			d = 5:
# 			prec for class acc = 0
# 			recall for class acc = 0.0
#
# 			prec for class good = 0
# 			recall for class good = 0.0
#
# 			prec for class unacc = 0.7002314814814815
# 			recall for class unacc = 1.0
#
# 			prec for class vgood = 0
# 			recall for class vgood = 0.0
#
# 			acc = 0.7002314814814815
#
# 		n = 90
# 			d = 2:
# 			prec for class acc = 0
# 			recall for class acc = 0.0
#
# 			prec for class good = 0
# 			recall for class good = 0.0
#
# 			prec for class unacc = 0.7002314814814815
# 			recall for class unacc = 1.0
#
# 			prec for class vgood = 0
# 			recall for class vgood = 0.0
#
# 			acc = 0.7002314814814815
#
# 			d = 3:
# 			prec for class good = 0
# 			recall for class good = 0.0
#
# 			prec for class acc = 0
# 			recall for class acc = 0.0
#
# 			prec for class unacc = 0.7002314814814815
# 			recall for class unacc = 1.0
#
# 			prec for class vgood = 0
# 			recall for class vgood = 0.0
#
# 			acc = 0.7002314814814815
#
# 			d = 4:
# 			prec for class acc = 0.4166666666666667
# 			recall for class acc = 0.013020833333333334
#
# 			prec for class good = 0
# 			recall for class good = 0.0
#
# 			prec for class unacc = 0.7027972027972028
# 			recall for class unacc = 0.996694214876033
#
# 			prec for class vgood = 0
# 			recall for class vgood = 0.0
#
# 			acc = 0.7008101851851852
#
# 			d = 5:
# 			prec for class acc = 0
# 			recall for class acc = 0.0
#
# 			prec for class good = 0
# 			recall for class good = 0.0
#
# 			prec for class unacc = 0.7002314814814815
# 			recall for class unacc = 1.0
#
# 			prec for class vgood = 0
# 			recall for class vgood = 0.0
#
# 			acc = 0.7002314814814815
#
# Testing dataset Chess
# 	Testing randomTree:
# 		d = 2:
# 		prec for class nowin = 0.5185031185031185
# 		recall for class nowin = 0.816633922724296
#
# 		prec for class won = 0.6460176991150443
# 		recall for class won = 0.30617136009586576
#
# 		acc = 0.5500625782227785
#
# 		d = 3:
# 		prec for class nowin = 0.6948775055679287
# 		recall for class nowin = 0.4086444007858546
#
# 		prec for class won = 0.6070496083550914
# 		recall for class won = 0.8358298382264829
#
# 		acc = 0.6317271589486858
#
# 		d = 4:
# 		prec for class nowin = 0.5793427230046948
# 		recall for class nowin = 0.404060248853962
#
# 		prec for class won = 0.5729704364148287
# 		recall for class won = 0.731575793888556
#
# 		acc = 0.5750938673341677
#
# 		d = 5:
# 		prec for class nowin = 0.6791044776119403
# 		recall for class nowin = 0.1787819253438114
#
# 		prec for class won = 0.5511811023622047
# 		recall for class won = 0.9227082085080887
#
# 		acc = 0.5672715894868585
#
# 	Testing ID3:
# 	prec for class nowin = 1.0
# 	recall for class nowin = 1.0
#
# 	prec for class won = 1.0
# 	recall for class won = 1.0
#
# 	acc = 1.0
#
# 	Testing randomForest with randomTrees:
# 		n = 10
# 			d = 2:
# 			prec for class nowin = 0.7215568862275449
# 			recall for class nowin = 0.15782580222658807
#
# 			prec for class won = 0.5506638714185884
# 			recall for class won = 0.9442780107849011
#
# 			acc = 0.568523153942428
#
# 			d = 3:
# 			prec for class nowin = 0.7016908212560387
# 			recall for class nowin = 0.3804846103470858
#
# 			prec for class won = 0.6005067567567568
# 			recall for class won = 0.8520071899340923
#
# 			acc = 0.626720901126408
#
# 			d = 4:
# 			prec for class nowin = 0.8469184890656064
# 			recall for class nowin = 0.27897838899803534
#
# 			prec for class won = 0.591162272558485
# 			recall for class won = 0.9538645895745955
#
# 			acc = 0.6314142678347935
#
# 			d = 5:
# 			prec for class nowin = 0.8225058004640371
# 			recall for class nowin = 0.46430910281597904
#
# 			prec for class won = 0.6495287060839761
# 			recall for class won = 0.908328340323547
#
# 			acc = 0.6961827284105131
#
# 		n = 20
# 			d = 2:
# 			prec for class nowin = 0.794392523364486
# 			recall for class nowin = 0.33398821218074654
#
# 			prec for class won = 0.6018010963194989
# 			recall for class won = 0.920910724985021
#
# 			acc = 0.640488110137672
#
# 			d = 3:
# 			prec for class nowin = 0.8155339805825242
# 			recall for class nowin = 0.4950884086444008
#
# 			prec for class won = 0.6602027324812693
# 			recall for class won = 0.8975434391851408
#
# 			acc = 0.7052565707133918
#
# 			d = 4:
# 			prec for class nowin = 0.930921052631579
# 			recall for class nowin = 0.555992141453831
#
# 			prec for class won = 0.7031523642732049
# 			recall for class won = 0.9622528460155781
#
# 			acc = 0.7681476846057572
#
# 			d = 5:
# 			prec for class nowin = 0.831081081081081
# 			recall for class nowin = 0.32220039292730845
#
# 			prec for class won = 0.6025345622119815
# 			recall for class won = 0.9400838825644098
#
# 			acc = 0.6448685857321652
#
# 		n = 30
# 			d = 2:
# 			prec for class nowin = 0.8561320754716981
# 			recall for class nowin = 0.23772102161100198
#
# 			prec for class won = 0.5800865800865801
# 			recall for class won = 0.96345116836429
#
# 			acc = 0.6167083854818524
#
# 			d = 3:
# 			prec for class nowin = 0.8832391713747646
# 			recall for class nowin = 0.6142763588736084
#
# 			prec for class won = 0.7239925023430178
# 			recall for class won = 0.9257040143798682
#
# 			acc = 0.7769086357947435
#
# 			d = 4:
# 			prec for class nowin = 0.7560756075607561
# 			recall for class nowin = 0.550098231827112
#
# 			prec for class won = 0.6705035971223021
# 			recall for class won = 0.8376273217495507
#
# 			acc = 0.700250312891114
#
# 			d = 5:
# 			prec for class nowin = 0.8396761133603239
# 			recall for class nowin = 0.679109364767518
#
# 			prec for class won = 0.7501274859765426
# 			recall for class won = 0.8813660874775314
#
# 			acc = 0.7847309136420526
#
# 		n = 40
# 			d = 2:
# 			prec for class nowin = 0.8696319018404908
# 			recall for class nowin = 0.3713163064833006
#
# 			prec for class won = 0.6226415094339622
# 			recall for class won = 0.9490713001797484
#
# 			acc = 0.6730287859824781
#
# 			d = 3:
# 			prec for class nowin = 0.8772189349112426
# 			recall for class nowin = 0.3883431565160445
#
# 			prec for class won = 0.6293650793650793
# 			recall for class won = 0.9502696225284601
#
# 			acc = 0.6817897371714643
#
# 			d = 4:
# 			prec for class nowin = 0.9292452830188679
# 			recall for class nowin = 0.38703339882121807
#
# 			prec for class won = 0.634375
# 			recall for class won = 0.9730377471539844
#
# 			acc = 0.6930538172715894
#
# 			d = 5:
# 			prec for class nowin = 0.9453032104637337
# 			recall for class nowin = 0.5206286836935167
#
# 			prec for class won = 0.689171974522293
# 			recall for class won = 0.9724385859796285
#
# 			acc = 0.7565707133917396
#
# 		n = 50
# 			d = 2:
# 			prec for class nowin = 0.8855721393034826
# 			recall for class nowin = 0.23313686967910938
#
# 			prec for class won = 0.5808876163206872
# 			recall for class won = 0.9724385859796285
#
# 			acc = 0.6192115143929913
#
# 			d = 3:
# 			prec for class nowin = 0.8661037394451147
# 			recall for class nowin = 0.4702030124426981
#
# 			prec for class won = 0.6582171525137305
# 			recall for class won = 0.9334931096464949
#
# 			acc = 0.7121401752190237
#
# 			d = 4:
# 			prec for class nowin = 0.9529529529529529
# 			recall for class nowin = 0.6234446627373936
#
# 			prec for class won = 0.7382794720072826
# 			recall for class won = 0.9718394248052726
#
# 			acc = 0.8053817271589487
#
# 			d = 5:
# 			prec for class nowin = 0.857293868921776
# 			recall for class nowin = 0.5311067452521283
#
# 			prec for class won = 0.6817777777777778
# 			recall for class won = 0.9191132414619533
#
# 			acc = 0.733729662077597
#
# 		n = 60
# 			d = 2:
# 			prec for class nowin = 0.8531400966183574
# 			recall for class nowin = 0.5782580222658809
#
# 			prec for class won = 0.7019898195279963
# 			recall for class won = 0.9089275014979029
#
# 			acc = 0.7509386733416771
#
# 			d = 3:
# 			prec for class nowin = 0.9301143583227446
# 			recall for class nowin = 0.4793713163064833
#
# 			prec for class won = 0.6699875466998755
# 			recall for class won = 0.9670461354104254
#
# 			acc = 0.7340425531914894
#
# 			d = 4:
# 			prec for class nowin = 0.9350253807106599
# 			recall for class nowin = 0.6031434184675835
#
# 			prec for class won = 0.7259158751696065
# 			recall for class won = 0.9616536848412223
#
# 			acc = 0.7903629536921152
#
# 			d = 5:
# 			prec for class nowin = 0.8593155893536122
# 			recall for class nowin = 0.5920104780615586
#
# 			prec for class won = 0.7094216417910447
# 			recall for class won = 0.9113241461953265
#
# 			acc = 0.7587609511889862
#
# 		n = 70
# 			d = 2:
# 			prec for class nowin = 0.9090909090909091
# 			recall for class nowin = 0.3798297314996726
#
# 			prec for class won = 0.6297888975762315
# 			recall for class won = 0.9652486518873576
#
# 			acc = 0.6855444305381727
#
# 			d = 3:
# 			prec for class nowin = 0.9645390070921985
# 			recall for class nowin = 0.26719056974459726
#
# 			prec for class won = 0.5964659213847818
# 			recall for class won = 0.9910125823846615
#
# 			acc = 0.6451814768460575
#
# 			d = 4:
# 			prec for class nowin = 0.8733480176211453
# 			recall for class nowin = 0.5193189259986902
#
# 			prec for class won = 0.6791958041958042
# 			recall for class won = 0.9310964649490713
#
# 			acc = 0.7343554443053817
#
# 			d = 5:
# 			prec for class nowin = 0.8854262144821264
# 			recall for class nowin = 0.6326129666011788
#
# 			prec for class won = 0.7334916864608076
# 			recall for class won = 0.9251048532055123
#
# 			acc = 0.7853566958698373
#
# 		n = 80
# 			d = 2:
# 			prec for class nowin = 0.9264705882352942
# 			recall for class nowin = 0.1650294695481336
#
# 			prec for class won = 0.563953488372093
# 			recall for class won = 0.988016776512882
#
# 			acc = 0.5948060075093867
#
# 			d = 3:
# 			prec for class nowin = 0.9769736842105263
# 			recall for class nowin = 0.3889980353634578
#
# 			prec for class won = 0.6394899536321483
# 			recall for class won = 0.9916117435590174
#
# 			acc = 0.7036921151439299
#
# 			d = 4:
# 			prec for class nowin = 0.8595927116827439
# 			recall for class nowin = 0.5252128356254093
#
# 			prec for class won = 0.6796288113124171
# 			recall for class won = 0.9215098861593769
#
# 			acc = 0.7321652065081352
#
# 			d = 5:
# 			prec for class nowin = 0.981888745148771
# 			recall for class nowin = 0.49705304518664045
#
# 			prec for class won = 0.6830375567478333
# 			recall for class won = 0.9916117435590174
#
# 			acc = 0.7553191489361702
#
# 		n = 90
# 			d = 2:
# 			prec for class nowin = 0.956221198156682
# 			recall for class nowin = 0.27177472167648986
#
# 			prec for class won = 0.5973931933381608
# 			recall for class won = 0.9886159376872379
#
# 			acc = 0.6461201501877347
#
# 			d = 3:
# 			prec for class nowin = 0.937007874015748
# 			recall for class nowin = 0.2337917485265226
#
# 			prec for class won = 0.5843694493783304
# 			recall for class won = 0.9856201318154584
#
# 			acc = 0.6264080100125157
#
# 			d = 4:
# 			prec for class nowin = 0.9537037037037037
# 			recall for class nowin = 0.40471512770137524
#
# 			prec for class won = 0.6432496075353218
# 			recall for class won = 0.982025164769323
#
# 			acc = 0.7061952440550688
#
# 			d = 5:
# 			prec for class nowin = 0.8901472253680635
# 			recall for class nowin = 0.5147347740667977
#
# 			prec for class won = 0.6796368352788587
# 			recall for class won = 0.9418813660874775
#
# 			acc = 0.7377972465581978
#
# Testing dataset Tennis
# 	Testing randomTree:
# 		d = 2:
# 		prec for class no = 0.6666666666666666
# 		recall for class no = 0.4
#
# 		prec for class yes = 0.7272727272727273
# 		recall for class yes = 0.8888888888888888
#
# 		acc = 0.7142857142857143
#
# 		d = 3:
# 		prec for class no = 0.6666666666666666
# 		recall for class no = 0.8
#
# 		prec for class yes = 0.875
# 		recall for class yes = 0.7777777777777778
#
# 		acc = 0.7857142857142857
#
# 		d = 4:
# 		prec for class no = 1.0
# 		recall for class no = 1.0
#
# 		prec for class yes = 1.0
# 		recall for class yes = 1.0
#
# 		acc = 1.0
#
# 		d = 5:
# 		prec for class no = 1.0
# 		recall for class no = 1.0
#
# 		prec for class yes = 1.0
# 		recall for class yes = 1.0
#
# 		acc = 1.0
#
# 	Testing ID3:
# 	prec for class no = 1.0
# 	recall for class no = 1.0
#
# 	prec for class yes = 1.0
# 	recall for class yes = 1.0
#
# 	acc = 1.0
#
# 	Testing randomForest with randomTrees:
# 		n = 10
# 			d = 2:
# 			prec for class no = 0.6
# 			recall for class no = 0.6
#
# 			prec for class yes = 0.7777777777777778
# 			recall for class yes = 0.7777777777777778
#
# 			acc = 0.7142857142857143
#
# 			d = 3:
# 			prec for class no = 0
# 			recall for class no = 0.0
#
# 			prec for class yes = 0.6428571428571429
# 			recall for class yes = 1.0
#
# 			acc = 0.6428571428571429
#
# 			d = 4:
# 			prec for class no = 1.0
# 			recall for class no = 0.2
#
# 			prec for class yes = 0.6923076923076923
# 			recall for class yes = 1.0
#
# 			acc = 0.7142857142857143
#
# 			d = 5:
# 			prec for class no = 0
# 			recall for class no = 0.0
#
# 			prec for class yes = 0.6428571428571429
# 			recall for class yes = 1.0
#
# 			acc = 0.6428571428571429
#
# 		n = 20
# 			d = 2:
# 			prec for class no = 0
# 			recall for class no = 0.0
#
# 			prec for class yes = 0.6428571428571429
# 			recall for class yes = 1.0
#
# 			acc = 0.6428571428571429
#
# 			d = 3:
# 			prec for class no = 0
# 			recall for class no = 0.0
#
# 			prec for class yes = 0.6428571428571429
# 			recall for class yes = 1.0
#
# 			acc = 0.6428571428571429
#
# 			d = 4:
# 			prec for class no = 0
# 			recall for class no = 0.0
#
# 			prec for class yes = 0.6428571428571429
# 			recall for class yes = 1.0
#
# 			acc = 0.6428571428571429
#
# 			d = 5:
# 			prec for class no = 0
# 			recall for class no = 0.0
#
# 			prec for class yes = 0.6428571428571429
# 			recall for class yes = 1.0
#
# 			acc = 0.6428571428571429
#
# 		n = 30
# 			d = 2:
# 			prec for class no = 0
# 			recall for class no = 0.0
#
# 			prec for class yes = 0.6428571428571429
# 			recall for class yes = 1.0
#
# 			acc = 0.6428571428571429
#
# 			d = 3:
# 			prec for class no = 0
# 			recall for class no = 0.0
#
# 			prec for class yes = 0.6428571428571429
# 			recall for class yes = 1.0
#
# 			acc = 0.6428571428571429
#
# 			d = 4:
# 			prec for class no = 0
# 			recall for class no = 0.0
#
# 			prec for class yes = 0.6428571428571429
# 			recall for class yes = 1.0
#
# 			acc = 0.6428571428571429
#
# 			d = 5:
# 			prec for class no = 0
# 			recall for class no = 0.0
#
# 			prec for class yes = 0.6428571428571429
# 			recall for class yes = 1.0
#
# 			acc = 0.6428571428571429
#
# 		n = 40
# 			d = 2:
# 			prec for class no = 0
# 			recall for class no = 0.0
#
# 			prec for class yes = 0.6428571428571429
# 			recall for class yes = 1.0
#
# 			acc = 0.6428571428571429
#
# 			d = 3:
# 			prec for class no = 0
# 			recall for class no = 0.0
#
# 			prec for class yes = 0.6428571428571429
# 			recall for class yes = 1.0
#
# 			acc = 0.6428571428571429
#
# 			d = 4:
# 			prec for class no = 0
# 			recall for class no = 0.0
#
# 			prec for class yes = 0.6428571428571429
# 			recall for class yes = 1.0
#
# 			acc = 0.6428571428571429
#
# 			d = 5:
# 			prec for class no = 0
# 			recall for class no = 0.0
#
# 			prec for class yes = 0.6428571428571429
# 			recall for class yes = 1.0
#
# 			acc = 0.6428571428571429
#
# 		n = 50
# 			d = 2:
# 			prec for class no = 0
# 			recall for class no = 0.0
#
# 			prec for class yes = 0
# 			recall for class yes = 0.0
#
# 			acc = 0.0
#
# 			d = 3:
# 			prec for class no = 0
# 			recall for class no = 0.0
#
# 			prec for class yes = 0
# 			recall for class yes = 0.0
#
# 			acc = 0.0
#
# 			d = 4:
# 			prec for class no = 0
# 			recall for class no = 0.0
#
# 			prec for class yes = 0
# 			recall for class yes = 0.0
#
# 			acc = 0.0
#
# 			d = 5:
# 			prec for class no = 0
# 			recall for class no = 0.0
#
# 			prec for class yes = 0
# 			recall for class yes = 0.0
#
# 			acc = 0.0
#
# 		n = 60
# 			d = 2:
# 			prec for class no = 0
# 			recall for class no = 0.0
#
# 			prec for class yes = 0
# 			recall for class yes = 0.0
#
# 			acc = 0.0
#
# 			d = 3:
# 			prec for class no = 0
# 			recall for class no = 0.0
#
# 			prec for class yes = 0
# 			recall for class yes = 0.0
#
# 			acc = 0.0
#
# 			d = 4:
# 			prec for class no = 0
# 			recall for class no = 0.0
#
# 			prec for class yes = 0
# 			recall for class yes = 0.0
#
# 			acc = 0.0
#
# 			d = 5:
# 			prec for class no = 0
# 			recall for class no = 0.0
#
# 			prec for class yes = 0
# 			recall for class yes = 0.0
#
# 			acc = 0.0
#
# 		n = 70
# 			d = 2:
# 			prec for class no = 0
# 			recall for class no = 0.0
#
# 			prec for class yes = 0
# 			recall for class yes = 0.0
#
# 			acc = 0.0
#
# 			d = 3:
# 			prec for class no = 0
# 			recall for class no = 0.0
#
# 			prec for class yes = 0
# 			recall for class yes = 0.0
#
# 			acc = 0.0
#
# 			d = 4:
# 			prec for class no = 0
# 			recall for class no = 0.0
#
# 			prec for class yes = 0
# 			recall for class yes = 0.0
#
# 			acc = 0.0
#
# 			d = 5:
# 			prec for class no = 0
# 			recall for class no = 0.0
#
# 			prec for class yes = 0
# 			recall for class yes = 0.0
#
# 			acc = 0.0
#
# 		n = 80
# 			d = 2:
# 			prec for class no = 0
# 			recall for class no = 0.0
#
# 			prec for class yes = 0
# 			recall for class yes = 0.0
#
# 			acc = 0.0
#
# 			d = 3:
# 			prec for class no = 0
# 			recall for class no = 0.0
#
# 			prec for class yes = 0
# 			recall for class yes = 0.0
#
# 			acc = 0.0
#
# 			d = 4:
# 			prec for class no = 0
# 			recall for class no = 0.0
#
# 			prec for class yes = 0
# 			recall for class yes = 0.0
#
# 			acc = 0.0
#
# 			d = 5:
# 			prec for class no = 0
# 			recall for class no = 0.0
#
# 			prec for class yes = 0
# 			recall for class yes = 0.0
#
# 			acc = 0.0
#
# 		n = 90
# 			d = 2:
# 			prec for class no = 0
# 			recall for class no = 0.0
#
# 			prec for class yes = 0
# 			recall for class yes = 0.0
#
# 			acc = 0.0
#
# 			d = 3:
# 			prec for class no = 0
# 			recall for class no = 0.0
#
# 			prec for class yes = 0
# 			recall for class yes = 0.0
#
# 			acc = 0.0
#
# 			d = 4:
# 			prec for class no = 0
# 			recall for class no = 0.0
#
# 			prec for class yes = 0
# 			recall for class yes = 0.0
#
# 			acc = 0.0
#
# 			d = 5:
# 			prec for class no = 0
# 			recall for class no = 0.0
#
# 			prec for class yes = 0
# 			recall for class yes = 0.0
#
# 			acc = 0.0

# %% [markdown]
# ## 7. Set de date
# În cadrul acestui laborator se vor folosi seturile de date [Car Evaluation](https://archive.ics.uci.edu/ml/datasets/Car+Evaluation), [Chess](https://archive.ics.uci.edu/ml/datasets/Chess+%28King-Rook+vs.+King-Pawn%29) și [Tennis](https://www.kaggle.com/fredericobreno/play-tennis).
#
# Aceste seturi de date sunt "ușor" modificate astfel încât pe prima linie să se afle atributele și labelul/clasa din care face parte fiecare exemplu.
#
# Atributele datasetului *Chess* nu sunt intuitive, iar dacă doriți să aflați mai multe informații despre acestea, puteți accesa link-ul de [aici](https://pdfs.semanticscholar.org/db58/88d3f373aff2c6bd7b2f956b81c6896874a9.pdf?_ga=2.193733611.798337455.1582711694-486327444.1582711694).

# %% [markdown]
# ## 8. Extra
# ### 8.1 ID3 exemplu
# Un exemplu mai detaliat pentru construcția arborelui de decizie ID3 se poate găsi [aici](https://github.com/cs-pub-ro/ML/blob/master/lab/lab2/id3_example.pdf).
#
# ### 8.2 CART
# Un alt algoritm utilizat poartă denumirea de CART (eng. Classification and Regression Tree). Dacă **ID3** utilizeaza **câștigul informațional (eng. information gain)**, **CART** utilizeaza o altă metrică numită **index-ul Gini (eng. Gini index sau Gini impurity)**.
#
# Pentru implementare, se urmăresc exact aceeași [pași ca la ID3](#scrollTo=rjYqUPSbe1gG), singura diferentă fiind modul în care se calculează atributul utilizat într-un *nod intermediar*.
# $$
# Gini(X, a) = 1 - \sum_{c \in C}{p(c | attr(X) = a) ^2}
# \\
# a^* = \underset{a \in A}{\operatorname{arg min}}\ Gini(X, a)
# $$
